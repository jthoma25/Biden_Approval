# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
#### APRIL 13 PIE CHART #####

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [32, 34, 32]

colors = ("red", "blue", "grey")

# %%
#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

# %%
#percent function
def func(pct, allvalues):
    ab = int(pct/98.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

# %%
#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 13th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 13th Pie Chart')

# %%
######## APRIL 14th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [34, 48, 33]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/115.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black") and {'fontsize': 16})

ax.set_title("April 14th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 14th Pie Chart')

# %%
######## APRIL 15th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [40, 59, 44]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/143.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black") and {'fontsize': 16})

ax.set_title("April 15th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 15th Pie Chart')

# %%
###### April 16th Chart########

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [34, 57, 26]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/117.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black") and {'fontsize': 16})

ax.set_title("April 16th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 16th Pie Chart')

# %%
######## APRIL 17th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [34, 39, 43]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/116.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 17th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 17th Pie Chart')

# %%
######## APRIL 18th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [19, 27, 41]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/87.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 18th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 18th Pie Chart')

# %%
######## APRIL 19th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [28, 39, 26]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/93.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 19th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 19th Pie Chart')

# %%
######## APRIL 20th PIE CHART ##############

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [24, 34, 40]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/98.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 20th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 20th Pie Chart')

# %%
twitter_apr = pd.read_csv("twitterapr.csv")
twitter_apr
# Out:
#       Date  negative  positive  neutral
# 0  4/13/22        32        34       32
# 1  4/14/22        34        48       33
# 2  4/15/22        40        59       44
# 3  4/16/22        34        57       26
# 4  4/17/22        34        39       43
# 5  4/18/22        19        27       41
# 6  4/19/22        28        39       26
# 7  4/20/22        24        34       40

# %%
#Bar Graph
ax = twitter_apr.plot.bar(x="Date", rot=0, color={"negative": "red", "positive": "blue", "neutral": "grey"})
ax.set_title("Biden Twitter Approval 4/13-4/20")
ax
# Out:
# Text(0.5, 1.0, 'Biden Twitter Approval 4/13-4/20')
# <AxesSubplot:title={'center':'Biden Twitter Approval 4/13-4/20'}, xlabel='Date'>

# %%
################ WEEK TWO ####################

##############  April 21 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [40, 45, 34]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/119.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 21st Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 21st Pie Chart')

# %%
##############  April 22 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [37, 42, 35]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/114.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 22nd Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 22nd Pie Chart')

# %%
##############  April 23 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [29, 37, 39]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/105.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 23rd Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 23rd Pie Chart')

# %%
##############  April 24 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [25, 37, 37]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/99.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 24th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 24th Pie Chart')

# %%
##############  April 25 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [51, 38, 48]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/137.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 25th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 25th Pie Chart')

# %%
##############  April 26 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [32, 31, 47]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/110.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 26th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 26th Pie Chart')

# %%
##############  April 27 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [30, 38, 38]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/106.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 27th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 27th Pie Chart')

# %%
##############  April 28 ##################

#Data
Type_of_tweet = ['negative', 'positive', 'neutral']

number = [33, 45, 34]

colors = ("red", "blue", "grey")

#Wedge width and color
wedge = {'linewidth':2, 'edgecolor':"black"}

#percent function
def func(pct, allvalues):
    ab = int(pct/112.*np.sum(allvalues))
    return "{:.1f}%".format(pct, ab)

#Plot
fig, ax = plt.subplots(figsize = (10, 7))
wedges, texts, autotexts = ax.pie(number, autopct = lambda pct: func(pct, number),
                                 labels = Type_of_tweet,
                                 colors = colors,
                                 shadow = True,
                                 startangle = 90,
                                 wedgeprops = wedge,
                                 textprops = dict(color = "black")  and {'fontsize': 16})

ax.set_title("April 28th Pie Chart")
#plt.pie(number, labels = Type_of_tweet)
plt.show()
# Out:
# Text(0.5, 1.0, 'April 28th Pie Chart')

# %%
twitter_apr2 = pd.read_csv("twitterapril_wk2.csv")
twitter_apr2
# Out:
#         Date  negative  positive  neutral
# 0  4/21/2022        40        45       34
# 1  4/22/2022        37        42       35
# 2  4/23/2022        29        37       39
# 3  4/24/2022        25        37       37
# 4  4/25/2022        51        38       48
# 5  4/26/2022        32        31       47
# 6  4/27/2022        30        38       38
# 7  4/28/2022        33        45       34

# %%
## BAR GRAPH WEEK 2 ######
ax2 = twitter_apr2.plot.bar(x="Date", rot=50, color={"negative": "red", "positive": "blue", "neutral": "grey"})
ax2.set_title("Biden Twitter Approval 4/21-4/28")
ax2
# Out:
# Text(0.5, 1.0, 'Biden Twitter Approval 4/21-4/28')
# <AxesSubplot:title={'center':'Biden Twitter Approval 4/21-4/28'}, xlabel='Date'>
